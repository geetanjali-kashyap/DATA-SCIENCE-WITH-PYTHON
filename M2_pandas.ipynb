# %% [markdown]
# # Module = 2

# %% [markdown]
# # Data Maipulation with pandas

# %% [markdown]
# ##Series

# %%
import pandas as pd
marks = [6,10,12,16,28]
DS = pd.Series(marks)
print((DS))
# Out:
# 0     6
# 1    10
# 2    12
# 3    16
# 4    28
# dtype: int64

# %%
import pandas as pd
marks = [6,10,12,16,28]
DS = pd.Series(marks)
DS
# Out:
# 0     6
# 1    10
# 2    12
# 3    16
# 4    28
# dtype: int64

# %%
import pandas as pd
marks = [6,10,12,16,28] #custmize index
DS = pd.Series(marks,index = ["A","B","C","D","E"])
print(DS)
# Out:
# A     6
# B    10
# C    12
# D    16
# E    28
# dtype: int64

# %%
import pandas as pd
marks = [6,10,12,16,28] #custmize index
DS = pd.Series(marks,index = ["A","B","C","D"])# length of values does not match length of index)(4)
print(DS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4223/3220335909.py in <cell line: 0>()
#       1 import pandas as pd
#       2 marks = [6,10,12,16,28] #custmize index
# ----> 3 DS = pd.Series(marks,index = ["A","B","C","D"])# length of values does not match length of index)(4)
#       4 print(DS)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     573             index = default_index(len(data))
#     574         elif is_list_like(data):
# --> 575             com.require_length_match(data, index)
#     576
#     577         # create/copy the manager
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
# ...

# %%
import pandas as pd
marks = [6,10,12,16,28] #custmize index
DS = pd.Series(marks,index = ["A","B","C","D","E","F"])#length of values(5) does not match length of index)(6)
print(DS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4223/1412011523.py in <cell line: 0>()
#       1 import pandas as pd
#       2 marks = [6,10,12,16,28] #custmize index
# ----> 3 DS = pd.Series(marks,index = ["A","B","C","D","E","F"])
#       4 print(DS)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     573             index = default_index(len(data))
#     574         elif is_list_like(data):
# --> 575             com.require_length_match(data, index)
#     576
#     577         # create/copy the manager
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ...

# %% [markdown]
# ##index and slicing

# %%
print("access element by int" ,DS ["A"])
# Out:
# access element by int 6

# %%
print("access element by varible = a,b,c," ,DS ["A"])
# Out:
# access element by varible = a,b,c, 6

# %%
print("Slicing in Series",DS[0:3])
# Out:
# Slicing in Series A     6
# B    10
# C    12
# dtype: int64

# %%
print("Slicing in Series",DS['A':'D'])
# Out:
# Slicing in Series A     6
# B    10
# C    12
# D    16
# dtype: int64

# %%
marks = [6,10,12,16,28] #custmize index
DS = pd.Series(marks,index = ["A","B","C","D","E"])
print(DS)

print("slicing in series " ,DS["A": "C"])
# Out:
# A     6
# B    10
# C    12
# D    16
# E    28
# dtype: int64
# slicing in series  A     6
# B    10
# C    12
# dtype: int64

# %% [markdown]
# ## Series operation

# %%
marks = [6,10,12,16,28] #custmize index
DS = pd.Series(marks,index = ["A","B","C","D","E"])
print(DS.sum())
# Out:
# 72

# %%
print(DS.mean())
# Out:
# 14.4

# %%
print(DS.max())
# Out:
# 28

# %%
print(DS.min())
# Out:
# 6

# %% [markdown]
# ## vectorized operator

# %%
DS*3
# Out:
# A    18
# B    30
# C    36
# D    48
# E    84
# dtype: int64

# %%
DS+2
# Out:
# A     8
# B    12
# C    14
# D    18
# E    30
# dtype: int64

# %%
DS -4
# Out:
# A     2
# B     6
# C     8
# D    12
# E    24
# dtype: int64

# %%
DS /2
# Out:
# A     3.0
# B     5.0
# C     6.0
# D     8.0
# E    14.0
# dtype: float64

# %%
DS %5
# Out:
# A    1
# B    0
# C    2
# D    1
# E    3
# dtype: int64

# %%
DS **3
# Out:
# A      216
# B     1000
# C     1728
# D     4096
# E    21952
# dtype: int64

# %%
import pandas as pd
# dict can be a series
info = {
    "name" : "geetanjali",
    'age' : 19,
    'marks' : [96,88,80.,54,]

}
DS1 = pd.Series(info)
print(DS1)
# Out:
# name             geetanjali
# age                      19
# marks    [96, 88, 80.0, 54]
# dtype: object

# %%
DS1.index
# Out:
# Index(['name', 'age', 'marks'], dtype='object')

# %%
(DS1["name"])
# Out:
# 'geetanjali'

# %% [markdown]
# # Create a series with single digit

# %%
num = pd.Series(10)
print(num)
# Out:
# 0    10
# dtype: int64

# %%
# we can create multi ple index with single values
num = pd.Series(10,index = [1,2,3,4,5])
print(num)
# Out:
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# dtype: int64

# %%
# addition of basic index
num1 = pd.Series(10,index = [1,2,3,4,5])
num2 = pd.Series(20,index = [6,2,0,8,9])
#nan = not a number
'''same index  additon will perform
but in case differnet index it will show NaN
'''
print(num1 + num2)
# Out:
# 0     NaN
# 1     NaN
# 2    30.0
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 8     NaN
# 9     NaN
# dtype: float64

# %%
num1 = pd.Series(10,index = [1,2,3,4,5])
num2 = pd.Series(20,index = [1,2,3,4,5])
print(num1 + num2)
# Out:
# 1    30
# 2    30
# 3    30
# 4    30
# 5    30
# dtype: int64

# %%
num1 = pd.Series(10,index = [1,2,3,4,5])
num2 = pd.Series(20,index = ["a","b","c","d","e"])
print(num1 + num2)
# Out:
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64

# %% [markdown]
# ## 2. main data structure
#
# ## Pandas DataFrame

# %%
student={
    'Name':['Pragya','Payal','Niahrika'],
    'Roll no.':[70,67,62],
    'Marks':[92,93,95]
}

df=pd.DataFrame(student)
print(df)
# Out:
#        Name  Roll no.  Marks
# 0    Pragya        70     92
# 1     Payal        67     93
# 2  Niahrika        62     95

# %%
# All arrays must be of the same length
student={
    'Name':['Pragya','Payal','Niahrika'],
    'Roll no.':[70,67,62],
    'Marks':[93,95]    #ValueError: All arrays must be of the same length
}

df=pd.DataFrame(student)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4223/2475343038.py in <cell line: 0>()
#       6 }
#       7
# ----> 8 df=pd.DataFrame(student)
#       9 print(df)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     501             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     502
# ...

# %%
# Creating a dataframe with list

student_info=[['a','b','c'],[20,30,40]]
df=pd.DataFrame(student_info)
df
#print(df)
# Out:
#     0   1   2
# 0   a   b   c
# 1  20  30  40

# %%
 #Creating dataframe with multiple series

 SR={
     'Name':pd.Series(['Pragya','Niharika','Payal']),
     'Roll no':pd.Series([70,67,62])
 }
 df=pd.DataFrame(SR)
df
# Out:
#        Name  Roll no
# 0    Pragya       70
# 1  Niharika       67
# 2     Payal       62

# %% [markdown]
# ##Arithmetic Opeartions

# %%
var=pd.DataFrame({'A':[1,2,3],'B':[3,5,6]})
var
# Out:
#    A  B
# 0  1  3
# 1  2  5
# 2  3  6

# %%
var["C"]=var['A']+var['B']
var
# Out:
#    A  B  C
# 0  1  3  4
# 1  2  5  7
# 2  3  6  9

# %% [markdown]
# ## Sorting

# %%
#filter
var['Python']=var["C"]>10
var
# Out:
#    A  B  C  Python
# 0  1  3  4   False
# 1  2  5  7   False
# 2  3  6  9   False

# %% [markdown]
# ##  hiding missing values

# %%
# create a dict. using np.NaN
#
import numpy as np
student={
    'Name':['Pragya','Payal','Niharika','Chhavi','Sarthak'],
    'Roll no.':[70,67,62,34,np.nan],
    'Marks':[92,93,np.nan,98,99],
    'Subject':['Chem',np.nan,'BIO',np.nan,'physics'],
    'City':['noida','noida','siwan',np.nan,np.nan]
}

df=pd.DataFrame(student)
df
# Out:
#        Name  Roll no.  Marks  Subject   City
# 0    Pragya      70.0   92.0     Chem  noida
# 1     Payal      67.0   93.0      NaN  noida
# 2  Niharika      62.0    NaN      BIO  siwan
# 3    Chhavi      34.0   98.0      NaN    NaN
# 4   Sarthak       NaN   99.0  physics    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5 non-null      object
#  1   Roll no.  4 non-null      float64
#  2   Marks     4 non-null      float64
#  3   Subject   3 non-null      object
#  4   City      3 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 332.0+ bytes

# %%
df.isnull()
# Out:
#     Name  Roll no.  Marks  Subject   City
# 0  False     False  False    False  False
# 1  False     False  False     True  False
# 2  False     False   True    False  False
# 3  False     False  False     True   True
# 4  False      True  False    False   True

# %%
df.isnull().sum()
# Out:
# Name        0
# Roll no.    1
# Marks       1
# Subject     2
# City        2
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 6

# %%
df.dropna()
# Out:
#      Name  Roll no.  Marks Subject   City
# 0  Pragya      70.0   92.0    Chem  noida

# %%
df['Marks']=df['Marks'].fillna(0)

# %%
df.dropna(subset=['Roll no.'])
# Out:
#        Name  Roll no.  Marks Subject   City
# 0    Pragya      70.0   92.0    Chem  noida
# 1     Payal      67.0   93.0     NaN  noida
# 2  Niharika      62.0    0.0     BIO  siwan
# 3    Chhavi      34.0   98.0     NaN    NaN

# %%
df['Marks']=df['Marks'].fillna(df['Marks'].mean())
print(df['Marks'])
# Out:
# 0    92.0
# 1    93.0
# 2     0.0
# 3    98.0
# 4    99.0
# Name: Marks, dtype: float64

# %%
df['Name'].fillna("unknown")
# Out:
# 0      Pragya
# 1       Payal
# 2    Niharika
# 3      Chhavi
# 4     Sarthak
# Name: Name, dtype: object

# %% [markdown]
# #Chapter = 2,Data cleaning and transformation

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-a3ee7dcd-323f-4a65-9855-f64a43273dd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3ee7dcd-323f-4a65-9855-f64a43273dd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/penguins (1).csv")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.head(5)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# check data types and missing values count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# check   missing values
df.isnull()
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# check total missing values per column
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
# get statistical summary of  numerical columns
df.describe()
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# count dublicates row and remove
# count dublicates row
print("duplicate value:\n", df.duplicated().sum())
# remove duplicates row
df.drop_duplicates(inplace= True)
# Out:
# duplicate value:
#  0

# %% [markdown]
# #chapter = 3, merging and joining dataframe

# %% [markdown]
# #merge

# %%
import pandas as  pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,4,6,8], "B":["A","C","E","F"]})
pd.merge(df1,df2)
# Out:
#    A  B
# 0  2  A
# 1  4  C

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,4,6,8], "B":["A","C","E","F"]})
df3 = pd.merge(df1,df2)
print(df3)
# Out:
#    A  B
# 0  2  A
# 1  4  C

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","D"]}) # get error if first column has 4 values and second column has 3 values
df2 = pd.DataFrame({"A":[2,4,6,8], "B":["A","C","E","F"]})
pd.merge(df1,df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_418/538885438.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","D"]})
#       3 df2 = pd.DataFrame({"A":[2,4,6,8], "B":["A","C","E","F"]})
#       4 pd.merge(df1,df2)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,4,6,8], "C":["A","C","E","F"]})
pd.merge(df1,df2)
# Out:
#    A  B  C
# 0  2  A  A
# 1  4  C  C

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,4,6,8], "B":["A","C","E","F"]})
pd.merge(df1,df2, on= ('A'),how ='inner')
# Out:
#    A B_x B_y
# 0  2   A   A
# 1  4   C   C

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,4,6,8], "C":["A","C","E","F"]})
pd.merge(df1,df2,on = ('A'),how = 'outer')
# Out:
#    A    B    C
# 0  2    A    A
# 1  3    B  NaN
# 2  4    C    C
# 3  5    D  NaN
# 4  6  NaN    E
# 5  8  NaN    F

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,4,6,8], "C":["A","C","E","F"]})
pd.merge(df1,df2,on = ('A'),how = 'left')
# Out:
#    A  B    C
# 0  2  A    A
# 1  3  B  NaN
# 2  4  C    C
# 3  5  D  NaN

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,4,6,8], "C":["A","C","E","F"]})
pd.merge(df1,df2,on = ('A'),how = 'right')
# Out:
#    A    B  C
# 0  2    A  A
# 1  4    C  C
# 2  6  NaN  E
# 3  8  NaN  F

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,], "B":[10,20,30,40]})
df2 = pd.DataFrame({"A":[1,2,3,4], "B":[100,200,300,400]})
pd.merge(df1,df2)
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
df1 = pd.DataFrame({"A":[1,2,3,4,], "B":[10,20,30,40]})
df2 = pd.DataFrame({"A":[1,2,3,4], "B":[100,200,300,400]})
pd.merge(df1,df2,on = ('A'),how= 'inner')
# Out:
#    A  B_x  B_y
# 0  1   10  100
# 1  2   20  200
# 2  3   30  300
# 3  4   40  400

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,3,4,5], "C":["E","F","G","H"]})
pd.merge(df1,df2,on = ('A'),how = 'left')
# Out:
#    A  B  C
# 0  2  A  E
# 1  3  B  F
# 2  4  C  G
# 3  5  D  H

# %%
df1 = pd.DataFrame({"roll_no":[12,13,14],"name":["A","B","C"]})
df2 = pd.DataFrame({"roll_no":[15,16,17],"name": ["E","F","G"]})
df3 = pd.merge(df1,df2)
print(df3)
# Out:
# Empty DataFrame
# Columns: [roll_no, name]
# Index: []

# %%
df1 = pd.DataFrame({"roll_no":[12,13,14],"name":["A","B","C"]})
df2 = pd.DataFrame({"roll_no":[15,16,17],"name": ["E","F","G"]})
pd.merge(df1,df2)
# Out:
# Empty DataFrame
# Columns: [roll_no, name]
# Index: []

# %%
import pandas as pd
df1 = pd.DataFrame({"roll":[12,13,14,15], "Name":["hanshi","shivi","harsh","vansh"]})
df2 = pd.DataFrame({"roll":[16,17,18,19], "Name":["sagar","ashi","Geetika","Harshita"]})
pd.merge(df1,df2,on ='roll',how = 'left')
# Out:
#    roll  Name_x Name_y
# 0    12  hanshi    NaN
# 1    13   shivi    NaN
# 2    14   harsh    NaN
# 3    15   vansh    NaN

# %%
import pandas as pd
df1 = pd.DataFrame({"roll":[12,13,14,15], "Name":["hanshi","shivi","harsh","vansh"]})
df2 = pd.DataFrame({"roll":[16,17,18,19], "Name":["sagar","ashi","Geetika","Harshita"]})
pd.merge(df1,df2,on = 'roll',how = 'right')
# Out:
#    roll Name_x    Name_y
# 0    16    NaN     sagar
# 1    17    NaN      ashi
# 2    18    NaN   Geetika
# 3    19    NaN  Harshita

# %%
import pandas as pd
df1 = pd.DataFrame({"roll":[12,13,14,15], "Name":["hanshi","shivi","harsh","vansh"]})
df2 = pd.DataFrame({"roll":[16,17,18,19], "Name":["sagar","ashi","Geetika","Harshita"]})
pd.merge(df1,df2,how = 'inner')
# Out:
# Empty DataFrame
# Columns: [roll, Name]
# Index: []

# %%
import pandas as pd
df1 = pd.DataFrame({"roll":[12,13,14,15], "Name":["hanshi","shivi","harsh","vansh"]})
df2 = pd.DataFrame({"roll":[16,17,18,19], "Name":["sagar","ashi","Geetika","Harshita"]})
pd.merge(df1,df2,how = 'outer')
# Out:
#    roll      Name
# 0    12    hanshi
# 1    13     shivi
# 2    14     harsh
# 3    15     vansh
# 4    16     sagar
# 5    17      ashi
# 6    18   Geetika
# 7    19  Harshita

# %%
import pandas as pd
df1 = pd.DataFrame({"roll":[12,13,14,15], "Name":["hanshi","shivi","harsh","vansh"]})
df2 = pd.DataFrame({"roll":[16,17,18,19], "Name":["sagar","ashi","Geetika","Harshita"]})
pd.merge(df1,df2,how = 'outer',indicator= True)
# Out:
#    roll      Name      _merge
# 0    12    hanshi   left_only
# 1    13     shivi   left_only
# 2    14     harsh   left_only
# 3    15     vansh   left_only
# 4    16     sagar  right_only
# 5    17      ashi  right_only
# 6    18   Geetika  right_only
# 7    19  Harshita  right_only

# %%
import pandas as pd
df1 = pd.DataFrame({"roll":[12,13,14,15], "Name":["hanshi","shivi","harsh","vansh"]})
df2 = pd.DataFrame({"roll":[16,17,18,19], "Name":["sagar","ashi","Geetika","Harshita"]})
pd.merge(df1,df2,how = 'outer',right_index=  True,left_index=True)
# Out:
#    roll_x  Name_x  roll_y    Name_y
# 0      12  hanshi      16     sagar
# 1      13   shivi      17      ashi
# 2      14   harsh      18   Geetika
# 3      15   vansh      19  Harshita

# %%
import pandas as pd
df1 = pd.DataFrame({"roll":[12,13,14,15], "Name":["hanshi","shivi","harsh","vansh"]})
df2 = pd.DataFrame({"roll":[16,17,18,19], "Name":["sagar","ashi","Geetika","Harshita"]})
pd.merge(df1,df2,right_index=  True,left_index=True)
# Out:
#    roll_x  Name_x  roll_y    Name_y
# 0      12  hanshi      16     sagar
# 1      13   shivi      17      ashi
# 2      14   harsh      18   Geetika
# 3      15   vansh      19  Harshita

# %%
import pandas as pd
_9 = pd.DataFrame({"roll":[1,2,3,4], "Name":["hanshi","shivi","harsh","vansh"]})
_10= pd.DataFrame({"roll":[1,2,3,4], "Name":["geetika","ashi","anjali","Harshita"]})
pd.merge(_9,_10,how = 'outer',right_index=True,left_index=True)
# Out:
#    roll_x  Name_x  roll_y    Name_y
# 0       1  hanshi       1   geetika
# 1       2   shivi       2      ashi
# 2       3   harsh       3    anjali
# 3       4   vansh       4  Harshita

# %%
import pandas as pd
_9 = pd.DataFrame({"roll":[1,2,3,4], "Name":["hanshi","shivi","harsh","vansh"]})
_10= pd.DataFrame({"roll":[1,2,3,4], "Name":["geetika","ashi","anjali","Harshita"]})
pd.merge(_9,_10,how = 'outer',suffixes=('_9','_10'),right_index=True,left_index=True)
# Out:
#    roll_9  Name_9  roll_10   Name_10
# 0       1  hanshi        1   geetika
# 1       2   shivi        2      ashi
# 2       3   harsh        3    anjali
# 3       4   vansh        4  Harshita

# %% [markdown]
# #join

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"D":[2,4,6,8], "C":["A","C","E","F"]})
df1.join(df2)

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]},index= [1,2,3,4])
df2 = pd.DataFrame({"D":[2,3,4,5], "C":["A","C","E","F"]})
df1.join(df2)
# Out:
#    A  B    D    C
# 1  2  A  3.0    C
# 2  3  B  4.0    E
# 3  4  C  5.0    F
# 4  5  D  NaN  NaN

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]},index= ["a","b","c","d"])
df2 = pd.DataFrame({"D":[2,3,4,5], "C":["A","C","E","F"]},index= ["a","b","c","d"])
df1.join(df2)
# Out:
#    A  B  D  C
# a  2  A  2  A
# b  3  B  3  C
# c  4  C  4  E
# d  5  D  5  F

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
df2 = pd.DataFrame({"B":[6,7], "D":["A","D"]},index=["f","g"])
df1.join(df2)
# Out:
#    A  C   B    D
# a  1  A NaN  NaN
# b  2  B NaN  NaN
# c  3  C NaN  NaN
# d  4  D NaN  NaN
# e  5  E NaN  NaN

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[2,3,4,5], "C":["A","B","C","D"]},index= ["a","b","c","d"])
df2 = pd.DataFrame({"B":[6,7], "D":["A","D"]},index=["e","f"])
df2.join(df1)
# Out:
#    B  D   A    C
# e  6  A NaN  NaN
# f  7  D NaN  NaN

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
df2 = pd.DataFrame({"B":[6,7], "D":["A","D"]},index=["f","g"])
df1.join(df2,how = 'inner')
# Out:
# Empty DataFrame
# Columns: [A, C, B, D]
# Index: []

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
df2 = pd.DataFrame({"B":[6,7], "D":["A","D"]},index=["f","g"])
df1.join(df2,how = 'left')
# Out:
#    A  C   B    D
# a  1  A NaN  NaN
# b  2  B NaN  NaN
# c  3  C NaN  NaN
# d  4  D NaN  NaN
# e  5  E NaN  NaN

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
df2 = pd.DataFrame({"B":[6,7], "D":["A","D"]},index=["f","g"])
df1.join(df2,how= 'right')
# Out:
#     A    C  B  D
# f NaN  NaN  6  A
# g NaN  NaN  7  D

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
df2 = pd.DataFrame({"B":[6,7], "D":["A","D"]},index=["f","g"])
df1.join(df2,how = 'outer')
# Out:
#      A    C    B    D
# a  1.0    A  NaN  NaN
# b  2.0    B  NaN  NaN
# c  3.0    C  NaN  NaN
# d  4.0    D  NaN  NaN
# e  5.0    E  NaN  NaN
# f  NaN  NaN  6.0    A
# g  NaN  NaN  7.0    D

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
df2 = pd.DataFrame({"A":[6,7], "D":["A","D"]},index=["f","g"])
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_418/4205631291.py in <cell line: 0>()
#       2 df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
#       3 df2 = pd.DataFrame({"A":[6,7], "D":["A","D"]},index=["f","g"])
# ----> 4 df1.join(df2)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10755                     validate=validate,
#   10756                 )
# > 10757             return merge(
#   10758                 self,
#   10759                 other,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     182             validate=validate,
#     183         )
# ...

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
df2 = pd.DataFrame({"B":[6,7], "D":["A","D"]},index=["f","g"])
df1.join(df2,lsuffix='_left')
# Out:
#    A  C   B    D
# a  1  A NaN  NaN
# b  2  B NaN  NaN
# c  3  C NaN  NaN
# d  4  D NaN  NaN
# e  5  E NaN  NaN

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4,5], "C":["A","B","C","D","E"]},index= ["a","b","c","d","e"])
df2 = pd.DataFrame({"B":[6,7], "D":["A","D"]},index=["f","g"])
df1.join(df2,lsuffix='_right')
# Out:
#    A  C   B    D
# a  1  A NaN  NaN
# b  2  B NaN  NaN
# c  3  C NaN  NaN
# d  4  D NaN  NaN
# e  5  E NaN  NaN

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"B":[5,6,7,8], "C":["E","F","G","H"]})
df3 = pd.DataFrame({"E":[9,10,11,12],"F":["I","J","k","L"]})
df1.join([df2,df3])# overlapping
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_418/3670272369.py in <cell line: 0>()
#       3 df2 = pd.DataFrame({"B":[5,6,7,8], "C":["E","F","G","H"]})
#       4 df3 = pd.DataFrame({"E":[9,10,11,12],"F":["I","J","k","L"]})
# ----> 5 df1.join([df2,df3])
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10788             if can_concat:
#   10789                 if how == "left":
# > 10790                     res = concat(
#   10791                         frames, axis=1, join="outer", verify_integrity=True, sort=sort
#   10792                     )
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     393     )
#     394
# --> 395     return op.get_result()
# ...

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"D":[5,6,7,8], "C":["E","F","G","H"]})
df3 = pd.DataFrame({"E":[9,10,11,12],"F":["I","J","k","L"]})
df1.join(df2).join(df3)
# Out:
#    A  B  D  C   E  F
# 0  1  A  5  E   9  I
# 1  2  B  6  F  10  J
# 2  3  C  7  G  11  k
# 3  4  D  8  H  12  L

# %%
import pandas as pd
df1 = pd.DataFrame({"name":["payal","shivi","hanshi","depanshi","harsh"],"rollno":[6061,6062,6063,6064,6065],"ID":["E2","E3","E4","E4","E5"]})
df2  = pd.DataFrame({"marks":[99,98,97,56,45],"subject":["ches","bio","math","phy","eng"]})
df1.join(df2)
# Out:
#        name  rollno  ID  marks subject
# 0     payal    6061  E2     99    ches
# 1     shivi    6062  E3     98     bio
# 2    hanshi    6063  E4     97    math
# 3  depanshi    6064  E4     56     phy
# 4     harsh    6065  E5     45     eng

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3,4], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"D":[5,6,7,8], "C":["E","F","G","H"]})
df3 = pd.DataFrame({"E":[9,10,11,12],"F":["I","J","k","L"]})

df4 = pd.DataFrame({"G":[13,14,15,17],"H":["M","N","O","P"]})
df5 =df1.join([df2,df3])
df5.join(df4)
# Out:
#    A  B  D  C   E  F   G  H
# 0  1  A  5  E   9  I  13  M
# 1  2  B  6  F  10  J  14  N
# 2  3  C  7  G  11  k  15  O
# 3  4  D  8  H  12  L  17  P

# %% [markdown]
# #Concat

# %%
import pandas as pd

# %%
rollno =pd.Series([6061,6062,6063,6064,6065])
rollno2 =pd.Series([6061,6062,6063,6064,6065])
pd.concat([rollno,rollno2],axis=0)
# Out:
# 0    6061
# 1    6062
# 2    6063
# 3    6064
# 4    6065
# 0    6061
# 1    6062
# 2    6063
# 3    6064
# 4    6065
# dtype: int64

# %%
rollno =pd.Series([6061,6062,6063,6064,6065])
rollno2 =pd.Series([6061,6062,6063,6064,6065])
pd.concat([rollno,rollno2],axis=1)
# Out:
#       0     1
# 0  6061  6061
# 1  6062  6062
# 2  6063  6063
# 3  6064  6064
# 4  6065  6065

# %%
rollno =pd.Series([6061,6062,6063,6064,6065])
rollno2 =pd.Series([6061,6062,6063,6064,6065])
pd.concat([rollno,rollno2],axis=0,ignore_index= True)
# Out:
# 0    6061
# 1    6062
# 2    6063
# 3    6064
# 4    6065
# 5    6061
# 6    6062
# 7    6063
# 8    6064
# 9    6065
# dtype: int64

# %%
rollno =pd.Series([6061,6062,6063,6064,6065])
rollno2 =pd.Series([6061,6062,6063,6064,6065])
pd.concat([rollno,rollno2],axis=0,ignore_index= False )
# Out:
# 0    6061
# 1    6062
# 2    6063
# 3    6064
# 4    6065
# 0    6061
# 1    6062
# 2    6063
# 3    6064
# 4    6065
# dtype: int64

# %%
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["AC","BI","C","D"]})
df2 = pd.DataFrame({"A":[2,3,4,5], "B":["AT","C","EG","F"]})
pd.concat([df1,df2],ignore_index=True)
# Out:
#    A   B
# 0  2  AC
# 1  3  BI
# 2  4   C
# 3  5   D
# 4  2  AT
# 5  3   C
# 6  4  EG
# 7  5   F

# %%
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,3,4,5], "B":["A","C","E","F"]})
pd.concat([df1,df2],how = 'right')#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_418/2065778308.py in <cell line: 0>()
#       1 df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
#       2 df2 = pd.DataFrame({"A":[2,3,4,5], "B":["A","C","E","F"]})
# ----> 3 pd.concat([df1,df2],how = 'right')#
#
# TypeError: concat() got an unexpected keyword argument 'how'

# %%
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,3,4,5], "B":["A","C","E","F"]})
pd.concat([df1,df2],axis = 1,keys= ["anjali","umang"])
# Out:
#   anjali    umang
#        A  B     A  B
# 0      2  A     2  A
# 1      3  B     3  C
# 2      4  C     4  E
# 3      5  D     5  F

# %%
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[2,3,4,5], "B":["A","C","E","F"]})
pd.concat([df1,df2],axis = 0,keys= ["anjali","umang"])
# Out:
#           A  B
# anjali 0  2  A
#        1  3  B
#        2  4  C
#        3  5  D
# umang  0  2  A
#        1  3  C
#        2  4  E
#        3  5  F

# %%
df1 = pd.DataFrame({"A":[2,3,4,5]})
df2 = pd.DataFrame({"A":[2,3,4,5], "B":["A","C","E","F"]})
pd.concat([df1,df2],axis = 1)
# Out:
#    A  A  B
# 0  2  2  A
# 1  3  3  C
# 2  4  4  E
# 3  5  5  F

# %%
df1 = pd.DataFrame({"A":[2,3,4,5]})
df2 = pd.DataFrame({"A":[2,3,4,5], "B":["A","C","E","F"]})
pd.concat([df1,df2],axis = 0,)
# Out:
#    A    B
# 0  2  NaN
# 1  3  NaN
# 2  4  NaN
# 3  5  NaN
# 0  2    A
# 1  3    C
# 2  4    E
# 3  5    F

# %%
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[20,30], "B":["A","B"]})
pd.concat([df1,df2],axis = 1)
# Out:
#    A  B     A    B
# 0  2  A  20.0    A
# 1  3  B  30.0    B
# 2  4  C   NaN  NaN
# 3  5  D   NaN  NaN

# %%
df1 = pd.DataFrame({"A":[2,3,4,5], "B":["A","B","C","D"]})
df2 = pd.DataFrame({"A":[20,30], "B":["A","B"]})
pd.concat([df1,df2],axis = 0)
# Out:
#     A  B
# 0   2  A
# 1   3  B
# 2   4  C
# 3   5  D
# 0  20  A
# 1  30  B
